# %% [markdown]
# # Crash Dataset: Project

# %% [markdown]
# ### About the dataset:
# * Dataset is from the department of homeland security.
# * Delaware crash reports.
# * 39 columns, 533115 entries.

# %% [markdown]
# ### Columns:
# * Crash Date and Time: Date and time at which the crash occurred.
# * Day of the week code: 01 - Sunday, 02 - Monday, 03 - Tuesday, 04 - Wednesday, 05 - Thursday, 06 - Friday, 07 - Saturday.
# * Day of the week description: Day of the week the crash occurred.
# * CRASH CLASSIFICATION CODE (TARGET VARIABLE): 01 - Non Reportable, 02 - Property damage only, 03 - personal injury crash, 04 - fatality crash.
# * CRASH CLASSIFICATION DESCRIPTION (ALSO TARGET VARIABLE): check the crash classification description in the pdf.
# * Collision on private property: No or Yes.
# * Pedestrian involved: indicates if a pedestrian was involved.
# * Manner of impact code: 01 - Front to rear, 02 - Front to front, 03 - Angle, 04 - Sideswipe (same direction), 05 - Sideswipe (opposite direction), 06 - Rear to side, 07 - Rear to rear, 88 - Other, 99 - Unknown, 00 - Not a collision between 2 vehicles.
# * Manner of impact description: gives the description.
# * Alcohol involved: Yes/No
# * Drug Involved: Yes/No
# * Road surface code: 01 - Dry, 02 - Wet, 03 - Snow, 04 - Ice/Frost, 05 - Sand, 06 - Water (standing/moving), 07 - Slush, 08 - Mud/dirt/gravel, 88- other, 99 - unknown.
# * Lighting condition description: description.
# * Weather 1 code: 01 - Clear, 02 - Cloudy, 03 - Fog/smoke/smog, 04 - Rain, 05 - sleet/hail (Freezing rain or drizzle), 06 - Snow, 07 - Blowing Snow, 08 - Severe Crosswinds, 09 - Blowing Sand/Soil/Dirt, 88 - Other, 99 - Unknown.
# * Weather 1 description - Description.
# * Weather 2 code: same thing as weather 1 (secondary weather condition)
# * Weather 2 description: Same as weather 1
# * Seatbelt used: Yes/No
# * Motorcycle involved: Yes/No
# * Motorcycle Helmet Used: Yes/No (Indicates whether a helmet was used by the people involved in the crash if a motorcycle or scooter was used.)
# * Bicycle involved: Yes/No
# * Bicycle helmet used: Yes/No
# * Latitude: Geographic latitude for the crash given in decimal degrees.
# * Longitude: Geographic longitude for the crash given in decimal degrees.
# * Primary Contributing Circumstance Code: 01 - Speeding, 02 - failed to yield right of way, Passed stop sign, 04 - disregard traffic signal, 05 - wrong side or wrong way,

# %%
import pandas as pd

# %%
crash_df = pd.read_csv("Public_Crash_Data_20250430.csv", low_memory=False)

# %%
print(crash_df.columns.tolist())
# Out:
# ['CRASH DATETIME', 'DAY OF WEEK CODE', 'DAY OF WEEK DESCRIPTION', 'CRASH CLASSIFICATION CODE', 'CRASH CLASSIFICATION DESCRIPTION', 'COLLISION ON PRIVATE PROPERTY', 'PEDESTRIAN INVOLVED', 'MANNER OF IMPACT CODE', 'MANNER OF IMPACT DESCRIPTION', 'ALCOHOL INVOLVED', 'DRUG INVOLVED', 'ROAD SURFACE CODE', 'ROAD SURFACE DESCRIPTION', 'LIGHTING CONDITION CODE', 'LIGHTING CONDITION DESCRIPTION', 'WEATHER 1 CODE', 'WEATHER 1 DESCRIPTION', 'WEATHER 2 CODE', 'WEATHER 2 DESCRIPTION', 'SEATBELT USED', 'MOTORCYCLE INVOLVED', 'MOTORCYCLE HELMET USED', 'BICYCLED INVOLVED', 'BICYCLE HELMET USED', 'LATITUDE', 'LONGITUDE', 'PRIMARY CONTRIBUTING CIRCUMSTANCE CODE', 'PRIMARY CONTRIBUTING CIRCUMSTANCE DESCRIPTION', 'SCHOOL BUS INVOLVED CODE', 'SCHOOL BUS INVOLVED DESCRIPTION', 'WORK ZONE', 'WORK ZONE LOCATION CODE', 'WORK ZONE LOCATION DESCRIPTION', 'WORK ZONE TYPE CODE', 'WORK ZONE TYPE DESCRIPTION', 'WORKERS PRESENT', 'the_geom', 'COUNTY CODE', 'COUNTY NAME']

# %%
print(crash_df.dtypes)
# Out:
# CRASH DATETIME                                    object
# DAY OF WEEK CODE                                   int64
# DAY OF WEEK DESCRIPTION                           object
# CRASH CLASSIFICATION CODE                         object
# CRASH CLASSIFICATION DESCRIPTION                  object
# COLLISION ON PRIVATE PROPERTY                     object
# PEDESTRIAN INVOLVED                               object
# MANNER OF IMPACT CODE                            float64
# MANNER OF IMPACT DESCRIPTION                      object
# ALCOHOL INVOLVED                                  object
# DRUG INVOLVED                                     object
# ROAD SURFACE CODE                                float64
# ROAD SURFACE DESCRIPTION                          object
# LIGHTING CONDITION CODE                          float64
# LIGHTING CONDITION DESCRIPTION                    object
# WEATHER 1 CODE                                   float64
# ...

# %%
# checking the missing values
crash_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 533115 entries, 0 to 533114
# Data columns (total 39 columns):
#  #   Column                                         Non-Null Count   Dtype
# ---  ------                                         --------------   -----
#  0   CRASH DATETIME                                 533112 non-null  object
#  1   DAY OF WEEK CODE                               533115 non-null  int64
#  2   DAY OF WEEK DESCRIPTION                        533115 non-null  object
#  3   CRASH CLASSIFICATION CODE                      533112 non-null  object
#  4   CRASH CLASSIFICATION DESCRIPTION               533086 non-null  object
#  5   COLLISION ON PRIVATE PROPERTY                  533115 non-null  object
#  6   PEDESTRIAN INVOLVED                            533115 non-null  object
#  7   MANNER OF IMPACT CODE                          513246 non-null  float64
#  8   MANNER OF IMPACT DESCRIPTION                   513243 non-null  object
# ...

# %%
print(crash_df.isnull().sum())
# Out:
# CRASH DATETIME                                        3
# DAY OF WEEK CODE                                      0
# DAY OF WEEK DESCRIPTION                               0
# CRASH CLASSIFICATION CODE                             3
# CRASH CLASSIFICATION DESCRIPTION                     29
# COLLISION ON PRIVATE PROPERTY                         0
# PEDESTRIAN INVOLVED                                   0
# MANNER OF IMPACT CODE                             19869
# MANNER OF IMPACT DESCRIPTION                      19872
# ALCOHOL INVOLVED                                      0
# DRUG INVOLVED                                         0
# ROAD SURFACE CODE                                 21107
# ROAD SURFACE DESCRIPTION                          21107
# LIGHTING CONDITION CODE                           20645
# LIGHTING CONDITION DESCRIPTION                    20645
# WEATHER 1 CODE                                    21499
# WEATHER 1 DESCRIPTION                             21499
# ...

# %%
print(crash_df['CRASH CLASSIFICATION DESCRIPTION'].unique())
# Out:
# ['Personal Injury Crash' 'Property Damage Only' 'Non-Reportable'
#  'Fatality Crash' nan]

# %%
print(crash_df['LIGHTING CONDITION DESCRIPTION'].unique())
# Out:
# ['Daylight' 'Dark-Not Lighted' 'Dark-Lighted' nan 'Dusk' 'Dawn' 'Unknown'
#  'Dark-Unknown Lighting' 'Other']

# %%
print(crash_df['WORK ZONE TYPE DESCRIPTION'].unique())
# Out:
# [nan 'Lane Closure' 'Intermittent or Moving Work' 'Other'
#  'Lane Shift/Crossover' 'Work on Shoulder or Median']

# %%
print(crash_df['PRIMARY CONTRIBUTING CIRCUMSTANCE DESCRIPTION'].unique())
# Out:
# ['Following too close' 'Failed to yield right of way'
#  'Driver inattention, distraction, or fatigue' nan
#  'Driving in a careless or reckless manner' 'Other improper driving'
#  'Unknown' 'Animal in Roadway - Deer' 'Improper backing' 'Speeding'
#  'Disregard Traffic Signal' 'Other' 'Improper lane change'
#  'Made improper turn' 'Driving under the influence' 'Passed Stop Sign'
#  'Other environmental circumstances - weather, glare' 'Mechanical defects'
#  'Improper passing' 'Roadway circumstances - debris, holes, work zone,'
#  'Animal in Roadway - Other Animal' 'Driving in an aggressive manner'
#  'Pedestrian' 'Wrong side or wrong way']

# %%
print(crash_df['WEATHER 1 DESCRIPTION'].unique())
# Out:
# ['Clear' 'Rain' 'Cloudy' 'Blowing Snow' nan 'Unknown' 'Snow'
#  'Sleet, Hail (freezing rain or drizzle)' 'Fog, Smog, Smoke'
#  'Severe Crosswinds' 'Other' 'Blowing Sand, Soil, Dirt']

# %%
print(crash_df['WEATHER 2 DESCRIPTION'].unique())
# Out:
# [nan 'Cloudy' 'Clear' 'Rain' 'Snow' 'Blowing Snow'
#  'Sleet, Hail (freezing rain or drizzle)' 'Severe Crosswinds' 'Other'
#  'Blowing Sand, Soil, Dirt' 'Fog, Smog, Smoke' 'Unknown']

# %%
print(crash_df['WORK ZONE LOCATION DESCRIPTION'].unique())
# Out:
# [nan 'Transition Area' 'Activity Area' 'Advance Warning Area'
#  'Termination Area' 'Before the First Work Zone Warning Sign']

# %%
print(crash_df['MANNER OF IMPACT DESCRIPTION'].unique())
# Out:
# ['Front to rear' 'Angle' 'Not a collision between two vehicles'
#  'Rear to side' 'Unknown' 'Sideswipe, same direction' nan 'Other'
#  'Sideswipe, opposite direction' 'Front to front' 'Rear to rear']

# %%
print(crash_df['SCHOOL BUS INVOLVED DESCRIPTION'].unique())
# Out:
# ['No' 'Yes, Directly Involved' 'Yes, Indirectly Involved' nan]

# %%
crash_df['SEATBELT USED'].value_counts()
# Out:
# SEATBELT USED
# Y    513056
# N     20059
# Name: count, dtype: int64

# %%
crash_df['DRUG INVOLVED'].value_counts()
# Out:
# DRUG INVOLVED
# N    526588
# Y      6527
# Name: count, dtype: int64

# %%
crash_df['CRASH CLASSIFICATION DESCRIPTION'].value_counts()
# Out:
# CRASH CLASSIFICATION DESCRIPTION
# Property Damage Only     300473
# Non-Reportable           147061
# Personal Injury Crash     83884
# Fatality Crash             1668
# Name: count, dtype: int64

# %%
crash_df['PEDESTRIAN INVOLVED'].value_counts()
# Out:
# PEDESTRIAN INVOLVED
# N    526069
# Y      7046
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
crash_df['CRASH DATETIME'] = pd.to_datetime(crash_df['CRASH DATETIME'])
crash_df['hour'] = crash_df['CRASH DATETIME'].dt.hour
crash_df['dayofweek'] = crash_df['CRASH DATETIME'].dt.day_name()
crash_df['month'] = crash_df['CRASH DATETIME'].dt.month

# Plot by hour
sns.histplot(data=crash_df, x='hour', hue='CRASH CLASSIFICATION DESCRIPTION', multiple = 'stack')
plt.title("Crashes by Hour")
# Out:
# /var/folders/1c/47fsk5z56lq4c2qq6c1rfj7r0000gn/T/ipykernel_55639/2124001811.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   crash_df['CRASH DATETIME'] = pd.to_datetime(crash_df['CRASH DATETIME'])
# Text(0.5, 1.0, 'Crashes by Hour')

# %%
weather_order = crash_df['WEATHER 1 DESCRIPTION'].value_counts().index
sns.countplot(data=crash_df, x='WEATHER 1 DESCRIPTION', hue='CRASH CLASSIFICATION DESCRIPTION', order=weather_order)
plt.xticks(rotation=45)
plt.title("Crash Severity by Weather Condition")
# Out:
# Text(0.5, 1.0, 'Crash Severity by Weather Condition')

# %%
import matplotlib.pyplot as plt
sns.set_style("whitegrid")

# Your normalized DataFrame
normalized = crash_df.groupby('ALCOHOL INVOLVED')['CRASH CLASSIFICATION DESCRIPTION']\
                     .value_counts(normalize=True).unstack()

# Plot with enhancements
ax = normalized.plot(kind='bar', stacked=False, figsize=(8, 5))

# Label the y-axis
ax.set_ylabel("Proportion of Crashes")

# Label the x-axis
ax.set_xlabel("Alcohol Involved")

# Title (optional)
ax.set_title("Crash Severity Distribution by Alcohol Involvement")

# Rotate x-axis labels (if needed)
plt.xticks(rotation=0)

# Improve legend
plt.legend(title='Crash Classification Description', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure 'year' column exists
crash_df['CRASH DATETIME'] = pd.to_datetime(crash_df['CRASH DATETIME'], errors='coerce')
crash_df['year'] = crash_df['CRASH DATETIME'].dt.year

# Drop rows with missing year just in case
crash_df = crash_df.dropna(subset=['year'])

# Plot
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")

ax = sns.countplot(data=crash_df, x='year', hue='CRASH CLASSIFICATION DESCRIPTION', palette='Set2')

ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
ax.set_xlabel("Year", fontsize=12)
ax.set_ylabel("Number of Crashes", fontsize=12)
ax.set_title("Crash Severity Distribution Over the Years", fontsize=14)
plt.legend(title="Crash Classification", bbox_to_anchor=(1.02, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/1c/47fsk5z56lq4c2qq6c1rfj7r0000gn/T/ipykernel_55639/1556234572.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# %%
# !pip install folium
import folium
from folium.plugins import HeatMap

sample = crash_df[crash_df['CRASH CLASSIFICATION DESCRIPTION'] == 'Fatality Crash'][['LATITUDE', 'LONGITUDE']].dropna()
m = folium.Map(location=[sample['LATITUDE'].mean(), sample['LONGITUDE'].mean()], zoom_start=8)
HeatMap(data=sample).add_to(m)
m.save('fatality_heatmap.html')

# %%
'''
Some columns have few missing values, some have many
There also some discrepancies between respective codes and descriptions

We will proceed as follows:
Missing 0% ---> Do nothing
Missing < 1% ---> Drop rows with missing values (3)
Missing < 5% ---> Fill in with the mode/most frequent value (4)
Missing > 5% ---> Drop columns entirely (2)

Convert missing codes to descriptions or vice versa (1)
'''
# Out:
# '\nSome columns have few missing values, some have many\nThere also some discrepancies between respective codes and descriptions\n\nWe will proceed as follows:\nMissing 0% ---> Do nothing\nMissing < 1% ---> Drop rows with missing values (3)\nMissing < 5% ---> Fill in with the mode/most frequent value (4)\nMissing > 5% ---> Drop columns entirely (2)\n\nConvert missing codes to descriptions or vice versa (1)\n'

# %%
'''
Strange values in columns with discrepancies:
CRASH CODE - 00, 33, 32, 31, also needs a lot of standardization
IMPACT CODE - 30
PRIMARY CIRCUMSTANCE CODE  - 43

These need to be handled/removed before converting codes-to-descriptions/descriptions-to-codes
'''
# Out:
# '\nStrange values in columns with discrepancies:\nCRASH CODE - 00, 33, 32, 31, also needs a lot of standardization\nIMPACT CODE - 30\nPRIMARY CIRCUMSTANCE CODE  - 43\n\nThese need to be handled/removed before converting codes-to-descriptions/descriptions-to-codes\n'

# %%
pd.set_option('display.max_columns', 39)
crash_df[crash_df['PRIMARY CONTRIBUTING CIRCUMSTANCE CODE'] == 43.0]
# Out:
#                   CRASH DATETIME  DAY OF WEEK CODE DAY OF WEEK DESCRIPTION  \
# 488328 2021-05-21 19:00:00+00:00                 6                  Friday
#
#        CRASH CLASSIFICATION CODE CRASH CLASSIFICATION DESCRIPTION  \
# 488328                        03            Personal Injury Crash
#
#        COLLISION ON PRIVATE PROPERTY PEDESTRIAN INVOLVED  \
# 488328                             N                   N
#
#         MANNER OF IMPACT CODE MANNER OF IMPACT DESCRIPTION ALCOHOL INVOLVED  \
# 488328                    1.0                Front to rear                N
#
#        DRUG INVOLVED  ROAD SURFACE CODE ROAD SURFACE DESCRIPTION  \
# 488328             N                1.0                      Dry
#
#         LIGHTING CONDITION CODE LIGHTING CONDITION DESCRIPTION  \
# 488328                      1.0                       Daylight
#
#         WEATHER 1 CODE WEATHER 1 DESCRIPTION  WEATHER 2 CODE  \
# 488328             1.0                 Clear             NaN
#
# ...

# %%
crash_df[crash_df['MANNER OF IMPACT CODE'] == 30.0]
# Out:
#                   CRASH DATETIME  DAY OF WEEK CODE DAY OF WEEK DESCRIPTION  \
# 524359 2018-05-22 20:52:00+00:00                 3                 Tuesday
#
#        CRASH CLASSIFICATION CODE CRASH CLASSIFICATION DESCRIPTION  \
# 524359                        02             Property Damage Only
#
#        COLLISION ON PRIVATE PROPERTY PEDESTRIAN INVOLVED  \
# 524359                             N                   N
#
#         MANNER OF IMPACT CODE MANNER OF IMPACT DESCRIPTION ALCOHOL INVOLVED  \
# 524359                   30.0                          NaN                N
#
#        DRUG INVOLVED  ROAD SURFACE CODE ROAD SURFACE DESCRIPTION  \
# 524359             N                1.0                      Dry
#
#         LIGHTING CONDITION CODE LIGHTING CONDITION DESCRIPTION  \
# 524359                      1.0                       Daylight
#
#         WEATHER 1 CODE WEATHER 1 DESCRIPTION  WEATHER 2 CODE  \
# 524359             1.0                 Clear             NaN
#
# ...

# %%
crash_df = crash_df[(crash_df['CRASH CLASSIFICATION CODE'] != '33') & 
           (crash_df['CRASH CLASSIFICATION CODE'] != '32') & 
           (crash_df['CRASH CLASSIFICATION CODE'] != '31') &
           (crash_df['CRASH CLASSIFICATION CODE'] != '00')]
crash_df['CRASH CLASSIFICATION CODE'] = '0' + crash_df['CRASH CLASSIFICATION CODE'].str[-1]

crash_df = crash_df[crash_df['MANNER OF IMPACT CODE'] != 30.0]

crash_df = crash_df[crash_df['PRIMARY CONTRIBUTING CIRCUMSTANCE CODE'] != 43.0]

crash_df.head()
# Out:
#              CRASH DATETIME  DAY OF WEEK CODE DAY OF WEEK DESCRIPTION  \
# 0 2015-11-18 17:06:00+00:00                 4               Wednesday
# 1 2013-10-11 22:53:00+00:00                 6                  Friday
# 2 2012-04-17 20:25:00+00:00                 3                 Tuesday
# 3 2013-07-24 16:20:00+00:00                 4               Wednesday
# 4 2009-09-18 15:02:00+00:00                 6                  Friday
#
#   CRASH CLASSIFICATION CODE CRASH CLASSIFICATION DESCRIPTION  \
# 0                        03            Personal Injury Crash
# 1                        03            Personal Injury Crash
# 2                        02             Property Damage Only
# 3                        02             Property Damage Only
# 4                        02             Property Damage Only
#
#   COLLISION ON PRIVATE PROPERTY PEDESTRIAN INVOLVED  MANNER OF IMPACT CODE  \
# 0                             N                   N                    1.0
# ...

# %%
percent_missing = (crash_df.isna().sum() / len(crash_df))[(crash_df.isna().sum() / len(crash_df)) > 0]
percent_missing
# Out:
# CRASH CLASSIFICATION CODE                        0.000006
# CRASH CLASSIFICATION DESCRIPTION                 0.000045
# MANNER OF IMPACT CODE                            0.037270
# MANNER OF IMPACT DESCRIPTION                     0.037274
# ROAD SURFACE CODE                                0.039593
# ROAD SURFACE DESCRIPTION                         0.039593
# LIGHTING CONDITION CODE                          0.038726
# LIGHTING CONDITION DESCRIPTION                   0.038726
# WEATHER 1 CODE                                   0.040328
# WEATHER 1 DESCRIPTION                            0.040328
# WEATHER 2 CODE                                   0.962114
# WEATHER 2 DESCRIPTION                            0.962114
# PRIMARY CONTRIBUTING CIRCUMSTANCE CODE           0.032525
# PRIMARY CONTRIBUTING CIRCUMSTANCE DESCRIPTION    0.032525
# SCHOOL BUS INVOLVED CODE                         0.000028
# SCHOOL BUS INVOLVED DESCRIPTION                  0.000028
# ...

# %%
percent_missing = (crash_df.isna().sum() / len(crash_df))[(crash_df.isna().sum() / len(crash_df)) > 0]
percent_missing
# Out:
# CRASH CLASSIFICATION CODE                        0.000006
# CRASH CLASSIFICATION DESCRIPTION                 0.000045
# MANNER OF IMPACT CODE                            0.037270
# MANNER OF IMPACT DESCRIPTION                     0.037274
# ROAD SURFACE CODE                                0.039593
# ROAD SURFACE DESCRIPTION                         0.039593
# LIGHTING CONDITION CODE                          0.038726
# LIGHTING CONDITION DESCRIPTION                   0.038726
# WEATHER 1 CODE                                   0.040328
# WEATHER 1 DESCRIPTION                            0.040328
# WEATHER 2 CODE                                   0.962114
# WEATHER 2 DESCRIPTION                            0.962114
# PRIMARY CONTRIBUTING CIRCUMSTANCE CODE           0.032525
# PRIMARY CONTRIBUTING CIRCUMSTANCE DESCRIPTION    0.032525
# SCHOOL BUS INVOLVED CODE                         0.000028
# SCHOOL BUS INVOLVED DESCRIPTION                  0.000028
# ...

# %%
percent_missing[percent_missing.between(0.01, 0.05)]
# Out:
# MANNER OF IMPACT CODE                            0.037270
# MANNER OF IMPACT DESCRIPTION                     0.037274
# ROAD SURFACE CODE                                0.039593
# ROAD SURFACE DESCRIPTION                         0.039593
# LIGHTING CONDITION CODE                          0.038726
# LIGHTING CONDITION DESCRIPTION                   0.038726
# WEATHER 1 CODE                                   0.040328
# WEATHER 1 DESCRIPTION                            0.040328
# PRIMARY CONTRIBUTING CIRCUMSTANCE CODE           0.032525
# PRIMARY CONTRIBUTING CIRCUMSTANCE DESCRIPTION    0.032525
# dtype: float64

# %%
percent_missing[percent_missing > 0.05]
# Out:
# WEATHER 2 CODE                    0.962114
# WEATHER 2 DESCRIPTION             0.962114
# WORK ZONE LOCATION CODE           0.992994
# WORK ZONE LOCATION DESCRIPTION    0.992994
# WORK ZONE TYPE CODE               0.992990
# WORK ZONE TYPE DESCRIPTION        0.992990
# dtype: float64

# %%
row_drop = list(percent_missing[percent_missing < 0.01].index)
row_drop
# Out:
# ['CRASH CLASSIFICATION CODE',
#  'CRASH CLASSIFICATION DESCRIPTION',
#  'SCHOOL BUS INVOLVED CODE',
#  'SCHOOL BUS INVOLVED DESCRIPTION']

# %%
row_fill = list(percent_missing[percent_missing.between(0.01, 0.05)].index)
row_fill
# Out:
# ['MANNER OF IMPACT CODE',
#  'MANNER OF IMPACT DESCRIPTION',
#  'ROAD SURFACE CODE',
#  'ROAD SURFACE DESCRIPTION',
#  'LIGHTING CONDITION CODE',
#  'LIGHTING CONDITION DESCRIPTION',
#  'WEATHER 1 CODE',
#  'WEATHER 1 DESCRIPTION',
#  'PRIMARY CONTRIBUTING CIRCUMSTANCE CODE',
#  'PRIMARY CONTRIBUTING CIRCUMSTANCE DESCRIPTION']

# %%
col_drop = list(percent_missing[percent_missing > 0.05].index)
col_drop
# Out:
# ['WEATHER 2 CODE',
#  'WEATHER 2 DESCRIPTION',
#  'WORK ZONE LOCATION CODE',
#  'WORK ZONE LOCATION DESCRIPTION',
#  'WORK ZONE TYPE CODE',
#  'WORK ZONE TYPE DESCRIPTION']

# %%
crash_df = crash_df.drop(col_drop, axis = 1)
crash_df
# Out:
#                   CRASH DATETIME  DAY OF WEEK CODE DAY OF WEEK DESCRIPTION  \
# 0      2015-11-18 17:06:00+00:00                 4               Wednesday
# 1      2013-10-11 22:53:00+00:00                 6                  Friday
# 2      2012-04-17 20:25:00+00:00                 3                 Tuesday
# 3      2013-07-24 16:20:00+00:00                 4               Wednesday
# 4      2009-09-18 15:02:00+00:00                 6                  Friday
# ...                          ...               ...                     ...
# 533110 2022-04-21 09:20:00+00:00                 5                Thursday
# 533111 2018-05-17 20:39:00+00:00                 5                Thursday
# 533112 2018-03-23 14:49:00+00:00                 6                  Friday
# 533113 2020-09-20 02:43:00+00:00                 7                Saturday
# 533114 2024-08-25 22:45:00+00:00                 1                  Sunday
#
#        CRASH CLASSIFICATION CODE CRASH CLASSIFICATION DESCRIPTION  \
# ...

# %%
crash_df = crash_df.dropna(subset = row_drop)
crash_df
# Out:
#                   CRASH DATETIME  DAY OF WEEK CODE DAY OF WEEK DESCRIPTION  \
# 0      2015-11-18 17:06:00+00:00                 4               Wednesday
# 1      2013-10-11 22:53:00+00:00                 6                  Friday
# 2      2012-04-17 20:25:00+00:00                 3                 Tuesday
# 3      2013-07-24 16:20:00+00:00                 4               Wednesday
# 4      2009-09-18 15:02:00+00:00                 6                  Friday
# ...                          ...               ...                     ...
# 533110 2022-04-21 09:20:00+00:00                 5                Thursday
# 533111 2018-05-17 20:39:00+00:00                 5                Thursday
# 533112 2018-03-23 14:49:00+00:00                 6                  Friday
# 533113 2020-09-20 02:43:00+00:00                 7                Saturday
# 533114 2024-08-25 22:45:00+00:00                 1                  Sunday
#
#        CRASH CLASSIFICATION CODE CRASH CLASSIFICATION DESCRIPTION  \
# ...

# %%
for col in row_fill:
    crash_df[col] = crash_df[col].fillna(crash_df[col].mode(dropna = True)[0])
crash_df
# Out:
# /var/folders/1c/47fsk5z56lq4c2qq6c1rfj7r0000gn/T/ipykernel_55639/701388996.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crash_df[col] = crash_df[col].fillna(crash_df[col].mode(dropna = True)[0])
#                   CRASH DATETIME  DAY OF WEEK CODE DAY OF WEEK DESCRIPTION  \
# 0      2015-11-18 17:06:00+00:00                 4               Wednesday
# 1      2013-10-11 22:53:00+00:00                 6                  Friday
# 2      2012-04-17 20:25:00+00:00                 3                 Tuesday
# 3      2013-07-24 16:20:00+00:00                 4               Wednesday
# 4      2009-09-18 15:02:00+00:00                 6                  Friday
# ...                          ...               ...                     ...
# ...

# %%
crash_df.isna().sum()
# Out:
# CRASH DATETIME                                   0
# DAY OF WEEK CODE                                 0
# DAY OF WEEK DESCRIPTION                          0
# CRASH CLASSIFICATION CODE                        0
# CRASH CLASSIFICATION DESCRIPTION                 0
# COLLISION ON PRIVATE PROPERTY                    0
# PEDESTRIAN INVOLVED                              0
# MANNER OF IMPACT CODE                            0
# MANNER OF IMPACT DESCRIPTION                     0
# ALCOHOL INVOLVED                                 0
# DRUG INVOLVED                                    0
# ROAD SURFACE CODE                                0
# ROAD SURFACE DESCRIPTION                         0
# LIGHTING CONDITION CODE                          0
# LIGHTING CONDITION DESCRIPTION                   0
# WEATHER 1 CODE                                   0
# WEATHER 1 DESCRIPTION                            0
# SEATBELT USED                                    0
# ...

# %%
crash_df.to_csv('clean_crash_data.csv', index = False)

# %% [markdown]
# # EDA and Feature Engineering

# %%
crash_df = pd.read_csv('clean_crash_data.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select numeric columns
numeric_cols = crash_df.select_dtypes(include=['number'])

# Compute correlation matrix
corr = numeric_cols.corr()

# Plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix of Numeric Features')
plt.show()

# %% [markdown]
# **High Correlations**
#
# ROAD SURFACE CODE vs WEATHER 1 CODE: 0.85
#
# LIGHTING CONDITION CODE vs WEATHER 1 CODE: 0.71
#
# ROAD SURFACE CODE vs WEATHER 1 CODE: 0.85
#
# This suggestes that these three may be describing overlapping information (bad weather -> wet roads -> poor lighting)
#
# **Moderate Corr**
#
# MANNER OF IMPACT CODE: 0.40
#
# ROAD SURFACE CODE, LIGHTING CONDITION, etc.: ~0.3
#
# These might interact or influence crash context and are worth keeping for modeling.
#
# => Heatmap shows feature relationship
# => Consider dropping either ROAD SURFACE CODE or WEATHER 1 CODE

# %%
from sklearn.feature_selection import mutual_info_classif
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# Prepare target
target = crash_df['CRASH CLASSIFICATION DESCRIPTION']

# Drop datetime and non-feature columns
X = crash_df.drop(columns=[col for col in crash_df.columns if 'DESCRIPTION' in col.upper()])
X = crash_df.drop(columns='CRASH CLASSIFICATION CODE')

# Drop Timestamp and geometry-related columns
X = X.drop(columns=[col for col in X.columns if 'DATE' in col or 'time' in col.lower() or 'geom' in col.lower() or 'LATITUDE' in col or 'LONGITUDE' in col], errors='ignore')

# Encode categorical features
X_encoded = X.copy()
for col in X_encoded.select_dtypes(include='object').columns:
    X_encoded[col] = LabelEncoder().fit_transform(X_encoded[col].astype(str))

# Compute mutual information
mi = mutual_info_classif(X_encoded, target, discrete_features='auto')

# Plot results
mi_series = pd.Series(mi, index=X_encoded.columns).sort_values(ascending=False)
mi_series.head(15).plot(kind='barh', figsize=(10, 6))
plt.title("Top Features by Mutual Information with Crash Severity")
plt.xlabel("Mutual Information Score")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# **TOP FEATURES**
#
# Collision on private property
#
# Primary contribution circumstance (directly reflects what caused the crash)
#
# Seatbelt used, manner of impact, lighting, weather, worker present
#
# => This shows feature-target associations
# Consider removing the others

# %%
from scipy.stats import chi2_contingency

cat_cols = crash_df.select_dtypes(include='object').columns
for col in cat_cols:
    if col != 'CRASH CLASSIFICATION DESCRIPTION':
        table = pd.crosstab(crash_df[col], crash_df['CRASH CLASSIFICATION DESCRIPTION'])
        chi2, p, dof, _ = chi2_contingency(table)
        print(f"{col}: p-value = {p:.4f}")
# Out:
# CRASH DATETIME: p-value = 0.0000
# DAY OF WEEK DESCRIPTION: p-value = 0.0000
# COLLISION ON PRIVATE PROPERTY: p-value = 0.0000
# PEDESTRIAN INVOLVED: p-value = 0.0000
# MANNER OF IMPACT DESCRIPTION: p-value = 0.0000
# ALCOHOL INVOLVED: p-value = 0.0000
# DRUG INVOLVED: p-value = 0.0000
# ROAD SURFACE DESCRIPTION: p-value = 0.0000
# LIGHTING CONDITION DESCRIPTION: p-value = 0.0000
# WEATHER 1 DESCRIPTION: p-value = 0.0000
# SEATBELT USED: p-value = 0.0000
# MOTORCYCLE INVOLVED: p-value = 0.0000
# MOTORCYCLE HELMET USED: p-value = 0.0000
# BICYCLED INVOLVED: p-value = 0.0000
# BICYCLE HELMET USED: p-value = 0.0000
# PRIMARY CONTRIBUTING CIRCUMSTANCE DESCRIPTION: p-value = 0.0000
# SCHOOL BUS INVOLVED DESCRIPTION: p-value = 0.0002
# WORK ZONE: p-value = 0.0000
# WORKERS PRESENT: p-value = 0.0000
# the_geom: p-value = 0.0000
# COUNTY CODE: p-value = 0.0000
# COUNTY NAME: p-value = 0.0000
# dayofweek: p-value = 0.0000

# %%
features_to_plot = [
    'ALCOHOL INVOLVED',
    'DRUG INVOLVED',
    'WORK ZONE',
    'PEDESTRIAN INVOLVED',
    'MOTORCYCLE INVOLVED',
    'BICYCLED INVOLVED',
    'SCHOOL BUS INVOLVED DESCRIPTION'
]

# %%
for feature in features_to_plot:
    if feature in crash_df.columns:
        cross = pd.crosstab(crash_df[feature], crash_df['CRASH CLASSIFICATION DESCRIPTION'], normalize='index')
        cross.plot(kind='bar', stacked=True, colormap='tab10', figsize=(8, 5))
        plt.title(f"Proportion of Crash Severity by {feature}")
        plt.ylabel("Proportion")
        plt.xlabel(feature)
        plt.legend(title="Crash Severity", bbox_to_anchor=(1.05, 1))
        plt.tight_layout()
        plt.show()

# %% [markdown]
# These plots help confirm the impact of rare but important features that is left out of the Mutual Information plot, thus we could see that 'ALCOHOL INVOLVED','DRUG INVOLVED', 'PEDESTRIAN INVOLVED', 'MOTORCYCLE INVOLVED', 'BICYCLED INVOLVED' does influence the severity of a crash. All of them have a chance to lead into a 'FATALITY CRASH' and increase the chance of 'PERSONAL INJURY CRASH'.

# %% [markdown]
# COULD START DROPPING COLUMNS BASED ON THIS

# %% [markdown]
# # FEATURE ENGINEERING

# %%
crash_df_fe = pd.read_csv('clean_crash_data.csv')

crash_df_fe= crash_df_fe.drop(columns=[col for col in crash_df_fe.columns if 'DESCRIPTION' in col.upper()])

# Continuous variables (already numeric)
continuous = ['LATITUDE', 'LONGITUDE', 'hour', 'dayofweek', 'month', 'year']

# Ordinal variables (could be label encoded or kept as-is if already numeric)
ordinal = [
    'CRASH CLASSIFICATION CODE',
    'DAY OF WEEK CODE',
    'MANNER OF IMPACT CODE',
    'ROAD SURFACE CODE',
    'LIGHTING CONDITION CODE',
    'WEATHER 1 CODE',
    'PRIMARY CONTRIBUTING CIRCUMSTANCE CODE',
    'SCHOOL BUS INVOLVED CODE'
]

# Nominal variables
nominal = [  
'COLLISION ON PRIVATE PROPERTY',  
'PEDESTRIAN INVOLVED',   
'ALCOHOL INVOLVED', 
'DRUG INVOLVED',  
'SEATBELT USED',  
'MOTORCYCLE INVOLVED',  
'MOTORCYCLE HELMET USED',  
'BICYCLED INVOLVED',  
'BICYCLE HELMET USED',
'WORK ZONE',  
'WORKERS PRESENT',  
]

# %%
# Binary mapping (Y/N → 1/0)
binary_mapping = {'Y': 1, 'YES': 1, '1': 1, 'N': 0, 'NO': 0, '0': 0}

# Apply to known binary columns
binary_columns = [
    'COLLISION ON PRIVATE PROPERTY',
    'PEDESTRIAN INVOLVED',
    'ALCOHOL INVOLVED',
    'DRUG INVOLVED',
    'SEATBELT USED',
    'MOTORCYCLE INVOLVED',
    'MOTORCYCLE HELMET USED',
    'BICYCLED INVOLVED',
    'BICYCLE HELMET USED',
    'WORK ZONE'
]

for col in binary_columns:
    if col in crash_df_fe.columns:
        crash_df_fe[col] = crash_df_fe[col].astype(str).str.strip().str.upper().map(binary_mapping).astype(int)

# %%
from sklearn.preprocessing import OneHotEncoder

# Nominal columns (filter out binary columns already converted)
nominal_multiclass = [col for col in nominal if col not in binary_columns and crash_df_fe[col].nunique() > 2]

# Apply one-hot encoding
crash_df_encoded = pd.get_dummies(crash_df_fe, columns=nominal_multiclass, drop_first=True)

bool_cols = crash_df_encoded.select_dtypes(include='bool').columns
crash_df_encoded[bool_cols] = crash_df_encoded[bool_cols].astype(int)

print("One-hot encoded columns:", nominal_multiclass)
crash_df_encoded.head()
# Out:
# One-hot encoded columns: ['WORKERS PRESENT']
#               CRASH DATETIME  DAY OF WEEK CODE  CRASH CLASSIFICATION CODE  \
# 0  2015-11-18 17:06:00+00:00                 4                          3
# 1  2013-10-11 22:53:00+00:00                 6                          3
# 2  2012-04-17 20:25:00+00:00                 3                          2
# 3  2013-07-24 16:20:00+00:00                 4                          2
# 4  2009-09-18 15:02:00+00:00                 6                          2
#
#    COLLISION ON PRIVATE PROPERTY  PEDESTRIAN INVOLVED  MANNER OF IMPACT CODE  \
# 0                              0                    0                    1.0
# 1                              0                    0                    3.0
# 2                              0                    0                    1.0
# 3                              0                    0                    1.0
# 4                              0                    0                    3.0
#
# ...

# %% [markdown]
# # PCA Analysis

# %%
# importing libraries
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
clean_df = pd.read_csv('clean_crash_data.csv')

# %%
# dropping the non numeric columns
non_numeric = ['CRASH CLASSIFICATION DESCRIPTION', 'CRASH DATETIME', 'COUNTY NAME']
X = clean_df.drop(columns=non_numeric, errors='ignore')

# %%
# identifying high cardinality columns
high_card = X.nunique().sort_values(ascending=False)
print(high_card.head(15))
# Out:
# the_geom                                         465106
# LATITUDE                                         113957
# LONGITUDE                                         78901
# hour                                                 24
# PRIMARY CONTRIBUTING CIRCUMSTANCE CODE               23
# PRIMARY CONTRIBUTING CIRCUMSTANCE DESCRIPTION        23
# year                                                 16
# month                                                12
# ROAD SURFACE CODE                                    11
# ROAD SURFACE DESCRIPTION                             11
# WEATHER 1 CODE                                       11
# WEATHER 1 DESCRIPTION                                11
# MANNER OF IMPACT DESCRIPTION                         10
# MANNER OF IMPACT CODE                                10
# LIGHTING CONDITION CODE                               8
# dtype: int64

# %%
# drop the_geom
X = X.drop(columns=['the_geom'])

# %%
# k means clustering to latitude/longitude
from sklearn.cluster import KMeans

# rows with valid coordinates
coord_df = clean_df[['LATITUDE', 'LONGITUDE']].dropna()

k = 10 

# fit kmeans
kmeans = KMeans(n_clusters=k, random_state=42)
clusters = kmeans.fit_predict(coord_df)


clean_df['LOCATION_CLUSTER'] = -1
clean_df.loc[coord_df.index, 'LOCATION_CLUSTER'] = clusters

# %%
# Drop the raw coordinates
X = clean_df.drop(columns=['the_geom', 'LATITUDE', 'LONGITUDE'], errors='ignore')

# %%
plt.figure(figsize=(6, 6))
sns.set_style("whitegrid")

sns.scatterplot(x='LONGITUDE', y='LATITUDE', hue='LOCATION_CLUSTER', data=clean_df, palette='tab10', alpha=0.5)
plt.title("Spatial Clusters of Crash Locations")
plt.show()

# %%
non_numeric_cols = X.select_dtypes(include=['object', 'datetime64']).columns
X = X.drop(columns=non_numeric_cols)

# %%
from sklearn.preprocessing import StandardScaler

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# identify object columns that would fail standardization
print(X.select_dtypes(include=['object', 'datetime64']).columns)
# Out:
# Index([], dtype='object')

# %%
from sklearn.decomposition import PCA

# enough components to explain 95% of the variance
pca = PCA(n_components=0.95)
X_pca = pca.fit_transform(X_scaled)

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(pca.explained_variance_ratio_) + 1),
         pca.explained_variance_ratio_.cumsum(), marker='o')
plt.xlabel("Number of Principal Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("Explained Variance by PCA Components")
plt.grid(True)
plt.show()

# %%
# top contributing features in PC1

pca_components = pd.DataFrame(
    pca.components_,
    columns=X.columns,
    index=[f'PC{i+1}' for i in range(pca.n_components_)]
)

top_features_pc1 = pca_components.loc['PC1'].abs().sort_values(ascending=False).head(10)
print("Top contributing features to PC1:")
print(top_features_pc1)
# Out:
# Top contributing features to PC1:
# WEATHER 1 CODE                            0.512828
# ROAD SURFACE CODE                         0.506329
# LIGHTING CONDITION CODE                   0.484566
# MANNER OF IMPACT CODE                     0.348024
# PRIMARY CONTRIBUTING CIRCUMSTANCE CODE    0.323885
# CRASH CLASSIFICATION CODE                 0.128950
# hour                                      0.051978
# SCHOOL BUS INVOLVED CODE                  0.014788
# month                                     0.013952
# DAY OF WEEK CODE                          0.005928
# Name: PC1, dtype: float64

# %%
y = clean_df['CRASH CLASSIFICATION DESCRIPTION']

# visualizing the first 2 components
plt.figure(figsize=(8,6))
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=y, alpha=0.5, palette='Set2')
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("Crash Data Projected on First Two Principal Components")
plt.legend(title="Crash Severity", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Clustering

# %%
df = clean_df

# %%
categorical_cols = [col for col in df.columns if col[-4:] != 'CODE' and col not in ['CRASH DATETIME', 'LATITUDE', 'LONGITUDE', 'the_geom', 'CRASH CLASSIFICATION DESCRIPTION', 'hour', 'dayofweek', 'month', 'year', 'LOCATION_CLUSTER']]
categorical_cols
# Out:
# ['DAY OF WEEK DESCRIPTION',
#  'COLLISION ON PRIVATE PROPERTY',
#  'PEDESTRIAN INVOLVED',
#  'MANNER OF IMPACT DESCRIPTION',
#  'ALCOHOL INVOLVED',
#  'DRUG INVOLVED',
#  'ROAD SURFACE DESCRIPTION',
#  'LIGHTING CONDITION DESCRIPTION',
#  'WEATHER 1 DESCRIPTION',
#  'SEATBELT USED',
#  'MOTORCYCLE INVOLVED',
#  'MOTORCYCLE HELMET USED',
#  'BICYCLED INVOLVED',
#  'BICYCLE HELMET USED',
#  'PRIMARY CONTRIBUTING CIRCUMSTANCE DESCRIPTION',
#  'SCHOOL BUS INVOLVED DESCRIPTION',
#  'WORK ZONE',
#  'WORKERS PRESENT',
#  'COUNTY NAME']

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.cluster import KMeans
from sklearn.compose import ColumnTransformer

high_card_cols = [col for col in categorical_cols if df[col].nunique() > 7]

ohe = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
ohe_encoded = ohe.fit_transform(df[high_card_cols])
ohe_col_names = ohe.get_feature_names_out(high_card_cols)
df_ohe = pd.DataFrame(ohe_encoded, columns=ohe_col_names, index=df.index)

# %%
high_card_cols
# Out:
# ['MANNER OF IMPACT DESCRIPTION',
#  'ROAD SURFACE DESCRIPTION',
#  'LIGHTING CONDITION DESCRIPTION',
#  'WEATHER 1 DESCRIPTION',
#  'PRIMARY CONTRIBUTING CIRCUMSTANCE DESCRIPTION']

# %%
def elbow_plot(df, col, max_k=10):
    values = df[col].dropna().astype(str)
    enc = OneHotEncoder(handle_unknown='ignore')
    encoded = enc.fit_transform(values.values.reshape(-1, 1))
    inertias = []
    for k in range(2, max_k+1):
        km = KMeans(n_clusters=k, random_state=42)
        km.fit(encoded)
        inertias.append(km.inertia_)
    plt.plot(range(2, max_k+1), inertias, marker='o')
    plt.title(f'{col}')
    plt.xlabel('Number of clusters')
    plt.grid(True)
    plt.show()

# %%
for col in high_card_cols:
    elbow_plot(df, col, max_k=10)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1473: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (9). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1473: ConvergenceWarning: Number of distinct clusters (8) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)

# %%
cluster_df = pd.DataFrame(index=df.index)
best_k = {
    'MANNER OF IMPACT DESCRIPTION': 5,
    'ROAD SURFACE DESCRIPTION': 4,
    'LIGHTING CONDITION DESCRIPTION': 3,
    'WEATHER 1 DESCRIPTION': 4,
    'PRIMARY CONTRIBUTING CIRCUMSTANCE DESCRIPTION': 5
}

for col, k in best_k.items():
    col_ohe = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
    col_encoded = col_ohe.fit_transform(df[[col]])
    kmeans = KMeans(n_clusters=k, random_state=3)
    clusters = kmeans.fit_predict(col_encoded)
    cluster_df[f'{col}_CLUSTER'] = clusters

df = pd.concat([df.reset_index(drop=True), cluster_df.reset_index(drop=True)], axis=1)

# %%
pd.set_option('display.max_columns', 500)
df.drop(['CRASH DATETIME', 'LATITUDE', 'LONGITUDE', 'the_geom', 'hour', 'dayofweek', 'month', 'year'], axis=1, inplace=True)
df
# Out:
#         DAY OF WEEK CODE DAY OF WEEK DESCRIPTION  CRASH CLASSIFICATION CODE  \
# 0                      4               Wednesday                          3
# 1                      6                  Friday                          3
# 2                      3                 Tuesday                          2
# 3                      4               Wednesday                          2
# 4                      6                  Friday                          2
# ...                  ...                     ...                        ...
# 533061                 5                Thursday                          2
# 533062                 5                Thursday                          2
# 533063                 6                  Friday                          1
# 533064                 7                Saturday                          2
# 533065                 1                  Sunday                          2
#
# ...

# %% [markdown]
# # Modeling

# %%
categorical_cols
# Out:
# ['DAY OF WEEK DESCRIPTION',
#  'COLLISION ON PRIVATE PROPERTY',
#  'PEDESTRIAN INVOLVED',
#  'MANNER OF IMPACT DESCRIPTION',
#  'ALCOHOL INVOLVED',
#  'DRUG INVOLVED',
#  'ROAD SURFACE DESCRIPTION',
#  'LIGHTING CONDITION DESCRIPTION',
#  'WEATHER 1 DESCRIPTION',
#  'SEATBELT USED',
#  'MOTORCYCLE INVOLVED',
#  'MOTORCYCLE HELMET USED',
#  'BICYCLED INVOLVED',
#  'BICYCLE HELMET USED',
#  'PRIMARY CONTRIBUTING CIRCUMSTANCE DESCRIPTION',
#  'SCHOOL BUS INVOLVED DESCRIPTION',
#  'WORK ZONE',
#  'WORKERS PRESENT',
#  'COUNTY NAME']

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.feature_selection import SelectFromModel
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder
import numpy as np

X = df[categorical_cols]
y = df['CRASH CLASSIFICATION DESCRIPTION']

le = LabelEncoder()
y= le.fit_transform(y)

encoder = ColumnTransformer([
    ('onehot', OneHotEncoder(), categorical_cols)
])

xgb = XGBClassifier(random_state = 3, eval_metric='mlogloss')

pipe = Pipeline([
    ('encode', encoder),
    ('model', xgb)
])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 3)

pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

# %%
print("Without clusters:")
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# Without clusters:
#                        precision    recall  f1-score   support
#
#        Fatality Crash       0.57      0.16      0.26       335
#        Non-Reportable       0.79      0.46      0.58     29509
# Personal Injury Crash       0.68      0.14      0.23     16630
#  Property Damage Only       0.65      0.93      0.77     60140
#
#              accuracy                           0.68    106614
#             macro avg       0.68      0.42      0.46    106614
#          weighted avg       0.70      0.68      0.63    106614

# %%
categorical_cols = [col for col in df.columns if col[-4:] != 'CODE' and col not in ['CRASH DATETIME', 'LATITUDE', 'LONGITUDE', 'the_geom', 'CRASH CLASSIFICATION DESCRIPTION', 'hour', 'dayofweek', 'month', 'year', 'COUNTY_NAME']]
categorical_cols
# Out:
# ['DAY OF WEEK DESCRIPTION',
#  'COLLISION ON PRIVATE PROPERTY',
#  'PEDESTRIAN INVOLVED',
#  'MANNER OF IMPACT DESCRIPTION',
#  'ALCOHOL INVOLVED',
#  'DRUG INVOLVED',
#  'ROAD SURFACE DESCRIPTION',
#  'LIGHTING CONDITION DESCRIPTION',
#  'WEATHER 1 DESCRIPTION',
#  'SEATBELT USED',
#  'MOTORCYCLE INVOLVED',
#  'MOTORCYCLE HELMET USED',
#  'BICYCLED INVOLVED',
#  'BICYCLE HELMET USED',
#  'PRIMARY CONTRIBUTING CIRCUMSTANCE DESCRIPTION',
#  'SCHOOL BUS INVOLVED DESCRIPTION',
#  'WORK ZONE',
#  'WORKERS PRESENT',
#  'COUNTY NAME',
#  'LOCATION_CLUSTER',
#  'MANNER OF IMPACT DESCRIPTION_CLUSTER',
#  'ROAD SURFACE DESCRIPTION_CLUSTER',
#  'LIGHTING CONDITION DESCRIPTION_CLUSTER',
#  'WEATHER 1 DESCRIPTION_CLUSTER',
#  'PRIMARY CONTRIBUTING CIRCUMSTANCE DESCRIPTION_CLUSTER']

# %%
X = df[categorical_cols]
y = df['CRASH CLASSIFICATION DESCRIPTION']

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y= le.fit_transform(y)

encoder = ColumnTransformer([
    ('onehot', OneHotEncoder(), categorical_cols)
])

xgb = XGBClassifier(random_state = 3, eval_metric='mlogloss')

pipe = Pipeline([
    ('encode', encoder),
    ('model', xgb)
])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 3)

pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

# %%
print("With clusters:")
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# With clusters:
#                        precision    recall  f1-score   support
#
#        Fatality Crash       0.63      0.17      0.26       335
#        Non-Reportable       0.79      0.46      0.58     29509
# Personal Injury Crash       0.68      0.14      0.23     16630
#  Property Damage Only       0.65      0.93      0.77     60140
#
#              accuracy                           0.68    106614
#             macro avg       0.69      0.43      0.46    106614
#          weighted avg       0.70      0.68      0.63    106614

# %%
categorical_cols = [col for col in df.columns if col[-4:] != 'CODE' and col not in ['CRASH DATETIME', 'LATITUDE', 'LONGITUDE', 'the_geom', 'CRASH CLASSIFICATION DESCRIPTION', 'hour', 'dayofweek', 'month', 'year']]

X = df[categorical_cols]
y = df['CRASH CLASSIFICATION DESCRIPTION']

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=3)

categorical_transformer = OneHotEncoder()

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_cols)
    ]
)

feature_selector = SelectFromModel(
    XGBClassifier(
        objective='multi:softmax',
        num_class=len(np.unique(y)),
        eval_metric='mlogloss',
        random_state=3
    ),
    threshold='median'
)

pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('feature_selection', feature_selector),
    ('classifier', XGBClassifier(
        objective='multi:softmax',
        num_class=len(np.unique(y)),
        eval_metric='mlogloss',
        random_state=3
    ))
])

pipeline.fit(X_train, y_train)

y_pred = pipeline.predict(X_test)
print("Best Selection")
print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
# Best Selection
#                        precision    recall  f1-score   support
#
#        Fatality Crash       0.58      0.17      0.26       335
#        Non-Reportable       0.79      0.46      0.58     29509
# Personal Injury Crash       0.67      0.14      0.23     16630
#  Property Damage Only       0.65      0.93      0.77     60140
#
#              accuracy                           0.68    106614
#             macro avg       0.68      0.43      0.46    106614
#          weighted avg       0.70      0.68      0.63    106614

# %%
ohe = pipeline.named_steps['preprocessor'].named_transformers_['cat']
encoded_feature_names = ohe.get_feature_names_out(categorical_cols)
encoded_feature_names[pipeline.named_steps['feature_selection'].get_support() == True]
# Out:
# array(['COLLISION ON PRIVATE PROPERTY_N', 'PEDESTRIAN INVOLVED_N',
#        'MANNER OF IMPACT DESCRIPTION_Angle',
#        'MANNER OF IMPACT DESCRIPTION_Front to front',
#        'MANNER OF IMPACT DESCRIPTION_Front to rear',
#        'MANNER OF IMPACT DESCRIPTION_Not a collision between two vehicles',
#        'MANNER OF IMPACT DESCRIPTION_Other',
#        'MANNER OF IMPACT DESCRIPTION_Rear to side',
#        'MANNER OF IMPACT DESCRIPTION_Sideswipe, opposite direction',
#        'MANNER OF IMPACT DESCRIPTION_Sideswipe, same direction',
#        'MANNER OF IMPACT DESCRIPTION_Unknown', 'ALCOHOL INVOLVED_N',
#        'DRUG INVOLVED_N', 'ROAD SURFACE DESCRIPTION_Dry',
#        'ROAD SURFACE DESCRIPTION_Snow',
#        'ROAD SURFACE DESCRIPTION_Unknown', 'ROAD SURFACE DESCRIPTION_Wet',
#        'LIGHTING CONDITION DESCRIPTION_Dark-Lighted',
#        'LIGHTING CONDITION DESCRIPTION_Dark-Not Lighted',
#        'LIGHTING CONDITION DESCRIPTION_Daylight',
# ...
