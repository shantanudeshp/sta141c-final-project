# %% [markdown]
# Loading data

# %%
import pandas as pd

# %%
crash_df = pd.read_csv('Public_Crash_Data_20250430.csv', low_memory = False)

# %%
crash_df.head()
# Out:
#                  CRASH DATETIME  DAY OF WEEK CODE DAY OF WEEK DESCRIPTION  \
# 0  11/18/2015 05:06:00 PM +0000                 4               Wednesday
# 1  10/11/2013 10:53:00 PM +0000                 6                  Friday
# 2  04/17/2012 08:25:00 PM +0000                 3                 Tuesday
# 3  07/24/2013 04:20:00 PM +0000                 4               Wednesday
# 4  09/18/2009 03:02:00 PM +0000                 6                  Friday
#
#   CRASH CLASSIFICATION CODE CRASH CLASSIFICATION DESCRIPTION  \
# 0                        03            Personal Injury Crash
# 1                        03            Personal Injury Crash
# 2                        02             Property Damage Only
# 3                        02             Property Damage Only
# 4                        02             Property Damage Only
#
#   COLLISION ON PRIVATE PROPERTY PEDESTRIAN INVOLVED  MANNER OF IMPACT CODE  \
# ...

# %% [markdown]
# Inspecting columns/unique values

# %%
'''
Our columns are all categorical
Some have few unique values, some have many
We will have to be careful with encoding choice
'''
# Out:
# '\nOur columns are all categorical\nSome have few unique values, some have many\nWe will have to be careful with encoding choice\n'

# %%
print(list(crash_df.columns))
# Out:
# ['CRASH DATETIME', 'DAY OF WEEK CODE', 'DAY OF WEEK DESCRIPTION', 'CRASH CLASSIFICATION CODE', 'CRASH CLASSIFICATION DESCRIPTION', 'COLLISION ON PRIVATE PROPERTY', 'PEDESTRIAN INVOLVED', 'MANNER OF IMPACT CODE', 'MANNER OF IMPACT DESCRIPTION', 'ALCOHOL INVOLVED', 'DRUG INVOLVED', 'ROAD SURFACE CODE', 'ROAD SURFACE DESCRIPTION', 'LIGHTING CONDITION CODE', 'LIGHTING CONDITION DESCRIPTION', 'WEATHER 1 CODE', 'WEATHER 1 DESCRIPTION', 'WEATHER 2 CODE', 'WEATHER 2 DESCRIPTION', 'SEATBELT USED', 'MOTORCYCLE INVOLVED', 'MOTORCYCLE HELMET USED', 'BICYCLED INVOLVED', 'BICYCLE HELMET USED', 'LATITUDE', 'LONGITUDE', 'PRIMARY CONTRIBUTING CIRCUMSTANCE CODE', 'PRIMARY CONTRIBUTING CIRCUMSTANCE DESCRIPTION', 'SCHOOL BUS INVOLVED CODE', 'SCHOOL BUS INVOLVED DESCRIPTION', 'WORK ZONE', 'WORK ZONE LOCATION CODE', 'WORK ZONE LOCATION DESCRIPTION', 'WORK ZONE TYPE CODE', 'WORK ZONE TYPE DESCRIPTION', 'WORKERS PRESENT', 'the_geom', 'COUNTY CODE', 'COUNTY NAME']

# %%
print(crash_df['CRASH CLASSIFICATION DESCRIPTION'].unique())
# Out:
# ['Personal Injury Crash' 'Property Damage Only' 'Non-Reportable'
#  'Fatality Crash' nan]

# %%
print(crash_df['LIGHTING CONDITION DESCRIPTION'].unique())
# Out:
# ['Daylight' 'Dark-Not Lighted' 'Dark-Lighted' nan 'Dusk' 'Dawn' 'Unknown'
#  'Dark-Unknown Lighting' 'Other']

# %%
print(crash_df['WORK ZONE TYPE DESCRIPTION'].unique())
# Out:
# [nan 'Lane Closure' 'Intermittent or Moving Work' 'Other'
#  'Lane Shift/Crossover' 'Work on Shoulder or Median']

# %%
print(crash_df['PRIMARY CONTRIBUTING CIRCUMSTANCE DESCRIPTION'].unique())
# Out:
# ['Following too close' 'Failed to yield right of way'
#  'Driver inattention, distraction, or fatigue' nan
#  'Driving in a careless or reckless manner' 'Other improper driving'
#  'Unknown' 'Animal in Roadway - Deer' 'Improper backing' 'Speeding'
#  'Disregard Traffic Signal' 'Other' 'Improper lane change'
#  'Made improper turn' 'Driving under the influence' 'Passed Stop Sign'
#  'Other environmental circumstances - weather, glare' 'Mechanical defects'
#  'Improper passing' 'Roadway circumstances - debris, holes, work zone,'
#  'Animal in Roadway - Other Animal' 'Driving in an aggressive manner'
#  'Pedestrian' 'Wrong side or wrong way']

# %%
print(crash_df['WEATHER 1 DESCRIPTION'].unique())
# Out:
# ['Clear' 'Rain' 'Cloudy' 'Blowing Snow' nan 'Unknown' 'Snow'
#  'Sleet, Hail (freezing rain or drizzle)' 'Fog, Smog, Smoke'
#  'Severe Crosswinds' 'Other' 'Blowing Sand, Soil, Dirt']

# %%
print(crash_df['WEATHER 2 DESCRIPTION'].unique())
# Out:
# [nan 'Cloudy' 'Clear' 'Rain' 'Snow' 'Blowing Snow'
#  'Sleet, Hail (freezing rain or drizzle)' 'Severe Crosswinds' 'Other'
#  'Blowing Sand, Soil, Dirt' 'Fog, Smog, Smoke' 'Unknown']

# %%
print(crash_df['WORK ZONE LOCATION DESCRIPTION'].unique())
# Out:
# [nan 'Transition Area' 'Activity Area' 'Advance Warning Area'
#  'Termination Area' 'Before the First Work Zone Warning Sign']

# %%
print(crash_df['MANNER OF IMPACT DESCRIPTION'].unique())
# Out:
# ['Front to rear' 'Angle' 'Not a collision between two vehicles'
#  'Rear to side' 'Unknown' 'Sideswipe, same direction' nan 'Other'
#  'Sideswipe, opposite direction' 'Front to front' 'Rear to rear']

# %%
print(crash_df['SCHOOL BUS INVOLVED DESCRIPTION'].unique())
# Out:
# ['No' 'Yes, Directly Involved' 'Yes, Indirectly Involved' nan]

# %% [markdown]
# Checking imbalance

# %%
'''
Getting idea of the mode/most frequent value
A lot of our columns are extremely unbalanced
'''
# Out:
# '\nGetting idea of the mode/most frequent value\nA lot of our columns are extremely unbalanced\n'

# %%
crash_df['SEATBELT USED'].value_counts()
# Out:
# SEATBELT USED
# Y    513056
# N     20059
# Name: count, dtype: int64

# %%
crash_df['ALCOHOL INVOLVED'].value_counts()
# Out:
# ALCOHOL INVOLVED
# N    512262
# Y     20853
# Name: count, dtype: int64

# %%
crash_df['DRUG INVOLVED'].value_counts()
# Out:
# DRUG INVOLVED
# N    526588
# Y      6527
# Name: count, dtype: int64

# %%
crash_df['CRASH CLASSIFICATION DESCRIPTION'].value_counts()
# Out:
# CRASH CLASSIFICATION DESCRIPTION
# Property Damage Only     300473
# Non-Reportable           147061
# Personal Injury Crash     83884
# Fatality Crash             1668
# Name: count, dtype: int64

# %%
crash_df['PEDESTRIAN INVOLVED'].value_counts()
# Out:
# PEDESTRIAN INVOLVED
# N    526069
# Y      7046
# Name: count, dtype: int64

# %%
crash_df['MOTORCYCLE INVOLVED'].value_counts()
# Out:
# MOTORCYCLE INVOLVED
# N    526458
# Y      6657
# Name: count, dtype: int64

# %%
crash_df['BICYCLED INVOLVED'].value_counts()
# Out:
# BICYCLED INVOLVED
# N    530076
# Y      3039
# Name: count, dtype: int64

# %%
crash_df['PRIMARY CONTRIBUTING CIRCUMSTANCE DESCRIPTION'].value_counts()
# Out:
# PRIMARY CONTRIBUTING CIRCUMSTANCE DESCRIPTION
# Driver inattention, distraction, or fatigue           121067
# Unknown                                                79386
# Following too close                                    53341
# Driving in a careless or reckless manner               41749
# Failed to yield right of way                           37690
# Animal in Roadway - Deer                               26638
# Other                                                  25337
# Improper lane change                                   21779
# Improper backing                                       20969
# Driving under the influence                            16708
# Disregard Traffic Signal                               11189
# Other environmental circumstances - weather, glare      9920
# Made improper turn                                      9001
# Mechanical defects                                      7044
# Other improper driving                                  5982
# ...

# %%
crash_df['LIGHTING CONDITION DESCRIPTION'].value_counts()
# Out:
# LIGHTING CONDITION DESCRIPTION
# Daylight                 328301
# Dark-Lighted              82621
# Dark-Not Lighted          62967
# Unknown                   16637
# Dusk                      11752
# Dawn                       7530
# Dark-Unknown Lighting      1986
# Other                       676
# Name: count, dtype: int64

# %%
crash_df['DAY OF WEEK DESCRIPTION'].value_counts()
# Out:
# DAY OF WEEK DESCRIPTION
# Friday       90550
# Thursday     79405
# Wednesday    78413
# Tuesday      76921
# Monday       75155
# Saturday     72991
# Sunday       59680
# Name: count, dtype: int64

# %%
crash_df['MANNER OF IMPACT DESCRIPTION'].value_counts()
# Out:
# MANNER OF IMPACT DESCRIPTION
# Front to rear                           166055
# Not a collision between two vehicles    101471
# Angle                                    96959
# Sideswipe, same direction                59955
# Unknown                                  29626
# Front to front                           18220
# Other                                    17946
# Sideswipe, opposite direction            10986
# Rear to side                              6624
# Rear to rear                              5401
# Name: count, dtype: int64

# %%
crash_df['WORK ZONE TYPE DESCRIPTION'].value_counts()
# Out:
# WORK ZONE TYPE DESCRIPTION
# Lane Closure                   1548
# Work on Shoulder or Median      945
# Lane Shift/Crossover            612
# Other                           407
# Intermittent or Moving Work     225
# Name: count, dtype: int64

# %%
crash_df['SCHOOL BUS INVOLVED DESCRIPTION'].value_counts()
# Out:
# SCHOOL BUS INVOLVED DESCRIPTION
# No                          529508
# Yes, Directly Involved        3493
# Yes, Indirectly Involved        99
# Name: count, dtype: int64

# %%
crash_df['BICYCLE HELMET USED'].value_counts()
# Out:
# BICYCLE HELMET USED
# N    530076
# Y      3039
# Name: count, dtype: int64

# %%
crash_df['MOTORCYCLE HELMET USED'].value_counts()
# Out:
# MOTORCYCLE HELMET USED
# N    530474
# Y      2641
# Name: count, dtype: int64

# %%
crash_df['WEATHER 1 DESCRIPTION'].value_counts()
# Out:
# WEATHER 1 DESCRIPTION
# Clear                                     356110
# Cloudy                                     72285
# Rain                                       51961
# Unknown                                    16596
# Snow                                        7656
# Fog, Smog, Smoke                            2353
# Sleet, Hail (freezing rain or drizzle)      2281
# Blowing Snow                                1376
# Other                                        516
# Severe Crosswinds                            458
# Blowing Sand, Soil, Dirt                      24
# Name: count, dtype: int64

# %%
crash_df['WEATHER 2 DESCRIPTION'].value_counts()
# Out:
# WEATHER 2 DESCRIPTION
# Clear                                     9953
# Cloudy                                    4046
# Rain                                      3648
# Snow                                       691
# Severe Crosswinds                          420
# Sleet, Hail (freezing rain or drizzle)     419
# Fog, Smog, Smoke                           324
# Blowing Snow                               270
# Other                                      198
# Unknown                                    179
# Blowing Sand, Soil, Dirt                    50
# Name: count, dtype: int64

# %%
crash_df['ROAD SURFACE DESCRIPTION'].value_counts()
# Out:
# ROAD SURFACE DESCRIPTION
# Dry                         400813
# Wet                          77653
# Unknown                      16050
# Snow                          7041
# Ice/Frost                     5188
# Slush                         2018
# Water (standing, moving)      1460
# Mud, Dirt, Gravel             1219
# Other                          387
# Sand                           138
# Oil                             41
# Name: count, dtype: int64

# %%
crash_df['WORKERS PRESENT'].value_counts()
# Out:
# WORKERS PRESENT
# N    529381
# 1      2133
# 2      1513
# 9        88
# Name: count, dtype: int64

# %% [markdown]
# Missing values

# %%
'''
Some columns have few missing values, some have many
There also some discrepancies between respective codes and descriptions

We will proceed as follows:
Missing 0% ---> Do nothing
Missing < 1% ---> Drop rows with missing values (3)
Missing < 5% ---> Fill in with the mode/most frequent value (4)
Missing > 5% ---> Drop columns entirely (2)

Convert missing codes to descriptions or vice versa (1)
'''
# Out:
# '\nSome columns have few missing values, some have many\nThere also some discrepancies between respective codes and descriptions\n\nWe will proceed as follows:\nMissing 0% ---> Do nothing\nMissing < 1% ---> Drop rows with missing values (3)\nMissing < 5% ---> Fill in with the mode/most frequent value (4)\nMissing > 5% ---> Drop columns entirely (2)\n\nConvert missing codes to descriptions or vice versa (1)\n'

# %%
crash_df.isna().sum()
# Out:
# CRASH DATETIME                                        3
# DAY OF WEEK CODE                                      0
# DAY OF WEEK DESCRIPTION                               0
# CRASH CLASSIFICATION CODE                             3
# CRASH CLASSIFICATION DESCRIPTION                     29
# COLLISION ON PRIVATE PROPERTY                         0
# PEDESTRIAN INVOLVED                                   0
# MANNER OF IMPACT CODE                             19869
# MANNER OF IMPACT DESCRIPTION                      19872
# ALCOHOL INVOLVED                                      0
# DRUG INVOLVED                                         0
# ROAD SURFACE CODE                                 21107
# ROAD SURFACE DESCRIPTION                          21107
# LIGHTING CONDITION CODE                           20645
# LIGHTING CONDITION DESCRIPTION                    20645
# WEATHER 1 CODE                                    21499
# WEATHER 1 DESCRIPTION                             21499
# ...

# %%
'''
Code to describe the ECRASH Report type crash classification: 
01 - Non-Reportable; 
02 - Property Damage Only; 
03 - Personal Injury Crash; 
04 - Fatality Crash;
'''
# Out:
# '\nCode to describe the ECRASH Report type crash classification: \n01 - Non-Reportable; \n02 - Property Damage Only; \n03 - Personal Injury Crash; \n04 - Fatality Crash;\n'

# %%
print(crash_df['CRASH CLASSIFICATION CODE'].unique())
# Out:
# ['03' '02' '01' '04' '00' nan "'1" '.2' '33' '.3' '1' '.1' '2' '32' '3'
#  '31']

# %%
'''
Code to describe the manner of impact: 
01 - Front to rear; 
02 - Front to front; 
03 - Angle; 
04 - Sideswipe, same direction; 
05 - Sideswipe, opposite direction; 
06 - Rear to side; 
07 - Rear to rear; 
88 - Other; 
99 - Unknown; 
00 - Not a collision between two vehicles;
'''
# Out:
# '\nCode to describe the manner of impact: \n01 - Front to rear; \n02 - Front to front; \n03 - Angle; \n04 - Sideswipe, same direction; \n05 - Sideswipe, opposite direction; \n06 - Rear to side; \n07 - Rear to rear; \n88 - Other; \n99 - Unknown; \n00 - Not a collision between two vehicles;\n'

# %%
print(crash_df['MANNER OF IMPACT CODE'].unique())
# Out:
# [ 1.  3.  0.  6. 99.  4. nan 88.  5.  2.  7. 30.]

# %%
'''
Code to describe the primary contributing circumstance: 
01 - Speeding; 
02 - Failed to yield right of way; 
03 - Passed Stop Sign; 
04 - Disregard Traffic Signal; 
05 - Wrong side or wrong way; 
06 - Improper passing; 
07 - Improper lane change; 
08 - Following too close; 
09 - Made improper turn; 
10 - Driving under the influence; 
11 - Driver inattention, distraction, or fatigue; 
12 - Driving in a careless or reckless manner; 
13 - Driving in an aggressive manner; 
14 - Improper backing; 
15 - Other improper driving; 
16 - Mechanical defects; 
17 - Animal in Roadway - Deer; 
18 - Animal in Roadway - Other Animal; 
19 - Other environmental circumstances - weather, glare, visibility obstructed, etc.; 
20 - Roadway circumstances - debris, holes, work zone, etc.; 
21 - Pedestrian; 
88 - Other; 
99 - Unknown;
'''
# Out:
# '\nCode to describe the primary contributing circumstance: \n01 - Speeding; \n02 - Failed to yield right of way; \n03 - Passed Stop Sign; \n04 - Disregard Traffic Signal; \n05 - Wrong side or wrong way; \n06 - Improper passing; \n07 - Improper lane change; \n08 - Following too close; \n09 - Made improper turn; \n10 - Driving under the influence; \n11 - Driver inattention, distraction, or fatigue; \n12 - Driving in a careless or reckless manner; \n13 - Driving in an aggressive manner; \n14 - Improper backing; \n15 - Other improper driving; \n16 - Mechanical defects; \n17 - Animal in Roadway - Deer; \n18 - Animal in Roadway - Other Animal; \n19 - Other environmental circumstances - weather, glare, visibility obstructed, etc.; \n20 - Roadway circumstances - debris, holes, work zone, etc.; \n21 - Pedestrian; \n88 - Other; \n99 - Unknown;\n'

# %%
print(crash_df['PRIMARY CONTRIBUTING CIRCUMSTANCE CODE'].unique())
# Out:
# [ 8.  2. 11. nan 12. 15. 99. 17. 14.  1.  4. 88.  7.  9. 10.  3. 19. 16.
#   6. 20. 18. 13. 21.  5. 43.]

# %%
'''
Strange values in columns with discrepancies:
CRASH CODE - 00, 33, 32, 31, also needs a lot of standardization
IMPACT CODE - 30
PRIMARY CIRCUMSTANCE CODE  - 43

These need to be handled/removed before converting codes-to-descriptions/descriptions-to-codes
'''
# Out:
# '\nStrange values in columns with discrepancies:\nCRASH CODE - 00, 33, 32, 31, also needs a lot of standardization\nIMPACT CODE - 30\nPRIMARY CIRCUMSTANCE CODE  - 43\n\nThese need to be handled/removed before converting codes-to-descriptions/descriptions-to-codes\n'

# %%
pd.set_option('display.max_columns', 39)
crash_df[crash_df['PRIMARY CONTRIBUTING CIRCUMSTANCE CODE'] == 43.0]
# Out:
#                       CRASH DATETIME  DAY OF WEEK CODE  \
# 488328  05/21/2021 07:00:00 PM +0000                 6
#
#        DAY OF WEEK DESCRIPTION CRASH CLASSIFICATION CODE  \
# 488328                  Friday                        03
#
#        CRASH CLASSIFICATION DESCRIPTION COLLISION ON PRIVATE PROPERTY  \
# 488328            Personal Injury Crash                             N
#
#        PEDESTRIAN INVOLVED  MANNER OF IMPACT CODE  \
# 488328                   N                    1.0
#
#        MANNER OF IMPACT DESCRIPTION ALCOHOL INVOLVED DRUG INVOLVED  \
# 488328                Front to rear                N             N
#
#         ROAD SURFACE CODE ROAD SURFACE DESCRIPTION  LIGHTING CONDITION CODE  \
# 488328                1.0                      Dry                      1.0
#
#        LIGHTING CONDITION DESCRIPTION  WEATHER 1 CODE WEATHER 1 DESCRIPTION  \
# 488328                       Daylight             1.0                 Clear
#
# ...

# %%
crash_df[crash_df['MANNER OF IMPACT CODE'] == 30.0]
# Out:
#                       CRASH DATETIME  DAY OF WEEK CODE  \
# 524359  05/22/2018 08:52:00 PM +0000                 3
#
#        DAY OF WEEK DESCRIPTION CRASH CLASSIFICATION CODE  \
# 524359                 Tuesday                        02
#
#        CRASH CLASSIFICATION DESCRIPTION COLLISION ON PRIVATE PROPERTY  \
# 524359             Property Damage Only                             N
#
#        PEDESTRIAN INVOLVED  MANNER OF IMPACT CODE  \
# 524359                   N                   30.0
#
#        MANNER OF IMPACT DESCRIPTION ALCOHOL INVOLVED DRUG INVOLVED  \
# 524359                          NaN                N             N
#
#         ROAD SURFACE CODE ROAD SURFACE DESCRIPTION  LIGHTING CONDITION CODE  \
# 524359                1.0                      Dry                      1.0
#
#        LIGHTING CONDITION DESCRIPTION  WEATHER 1 CODE WEATHER 1 DESCRIPTION  \
# 524359                       Daylight             1.0                 Clear
#
# ...

# %%
crash_df = crash_df[(crash_df['CRASH CLASSIFICATION CODE'] != '33') & 
           (crash_df['CRASH CLASSIFICATION CODE'] != '32') & 
           (crash_df['CRASH CLASSIFICATION CODE'] != '31') &
           (crash_df['CRASH CLASSIFICATION CODE'] != '00')]
crash_df['CRASH CLASSIFICATION CODE'] = '0' + crash_df['CRASH CLASSIFICATION CODE'].str[-1]

crash_df = crash_df[crash_df['MANNER OF IMPACT CODE'] != 30.0]

crash_df = crash_df[crash_df['PRIMARY CONTRIBUTING CIRCUMSTANCE CODE'] != 43.0]

crash_df.head()
# Out:
#                  CRASH DATETIME  DAY OF WEEK CODE DAY OF WEEK DESCRIPTION  \
# 0  11/18/2015 05:06:00 PM +0000                 4               Wednesday
# 1  10/11/2013 10:53:00 PM +0000                 6                  Friday
# 2  04/17/2012 08:25:00 PM +0000                 3                 Tuesday
# 3  07/24/2013 04:20:00 PM +0000                 4               Wednesday
# 4  09/18/2009 03:02:00 PM +0000                 6                  Friday
#
#   CRASH CLASSIFICATION CODE CRASH CLASSIFICATION DESCRIPTION  \
# 0                        03            Personal Injury Crash
# 1                        03            Personal Injury Crash
# 2                        02             Property Damage Only
# 3                        02             Property Damage Only
# 4                        02             Property Damage Only
#
#   COLLISION ON PRIVATE PROPERTY PEDESTRIAN INVOLVED  MANNER OF IMPACT CODE  \
# ...

# %%
crash_df['CRASH CLASSIFICATION CODE'].value_counts()
# Out:
# CRASH CLASSIFICATION CODE
# 02    300479
# 01    147069
# 03     83889
# 04      1668
# Name: count, dtype: int64

# %%
code_desc_pairs = [
    ('CRASH CLASSIFICATION CODE', 'CRASH CLASSIFICATION DESCRIPTION'),
    ('MANNER OF IMPACT CODE', 'MANNER OF IMPACT DESCRIPTION'),
    ('PRIMARY CONTRIBUTING CIRCUMSTANCE CODE', 'PRIMARY CONTRIBUTING CIRCUMSTANCE DESCRIPTION')]

for code_col, desc_col in code_desc_pairs:
    mapping = crash_df[[code_col, desc_col]].dropna().drop_duplicates()
    code_to_desc = dict(zip(mapping[code_col], mapping[desc_col]))
    desc_to_code = dict(zip(mapping[desc_col], mapping[code_col]))
    crash_df.loc[crash_df[desc_col].isna() & crash_df[code_col].notna(), desc_col] = crash_df.loc[crash_df[desc_col].isna() & crash_df[code_col].notna(), code_col].map(code_to_desc)
    crash_df.loc[crash_df[code_col].isna() & crash_df[desc_col].notna(), code_col] = crash_df.loc[crash_df[code_col].isna() & crash_df[desc_col].notna(), desc_col].map(desc_to_code)

# %% [markdown]
# All discrepancies have been resolved, now proceeding to dealing with missing values

# %%
crash_df.isna().sum()
# Out:
# CRASH DATETIME                                        3
# DAY OF WEEK CODE                                      0
# DAY OF WEEK DESCRIPTION                               0
# CRASH CLASSIFICATION CODE                             3
# CRASH CLASSIFICATION DESCRIPTION                      3
# COLLISION ON PRIVATE PROPERTY                         0
# PEDESTRIAN INVOLVED                                   0
# MANNER OF IMPACT CODE                             19869
# MANNER OF IMPACT DESCRIPTION                      19869
# ALCOHOL INVOLVED                                      0
# DRUG INVOLVED                                         0
# ROAD SURFACE CODE                                 21107
# ROAD SURFACE DESCRIPTION                          21107
# LIGHTING CONDITION CODE                           20645
# LIGHTING CONDITION DESCRIPTION                    20645
# WEATHER 1 CODE                                    21499
# WEATHER 1 DESCRIPTION                             21499
# ...

# %%
crash_df.isna().sum() / len(crash_df)
# Out:
# CRASH DATETIME                                   0.000006
# DAY OF WEEK CODE                                 0.000000
# DAY OF WEEK DESCRIPTION                          0.000000
# CRASH CLASSIFICATION CODE                        0.000006
# CRASH CLASSIFICATION DESCRIPTION                 0.000006
# COLLISION ON PRIVATE PROPERTY                    0.000000
# PEDESTRIAN INVOLVED                              0.000000
# MANNER OF IMPACT CODE                            0.037270
# MANNER OF IMPACT DESCRIPTION                     0.037270
# ALCOHOL INVOLVED                                 0.000000
# DRUG INVOLVED                                    0.000000
# ROAD SURFACE CODE                                0.039592
# ROAD SURFACE DESCRIPTION                         0.039592
# LIGHTING CONDITION CODE                          0.038726
# LIGHTING CONDITION DESCRIPTION                   0.038726
# WEATHER 1 CODE                                   0.040328
# ...

# %%
percent_missing = (crash_df.isna().sum() / len(crash_df))[(crash_df.isna().sum() / len(crash_df)) > 0]
percent_missing
# Out:
# CRASH DATETIME                                   0.000006
# CRASH CLASSIFICATION CODE                        0.000006
# CRASH CLASSIFICATION DESCRIPTION                 0.000006
# MANNER OF IMPACT CODE                            0.037270
# MANNER OF IMPACT DESCRIPTION                     0.037270
# ROAD SURFACE CODE                                0.039592
# ROAD SURFACE DESCRIPTION                         0.039592
# LIGHTING CONDITION CODE                          0.038726
# LIGHTING CONDITION DESCRIPTION                   0.038726
# WEATHER 1 CODE                                   0.040328
# WEATHER 1 DESCRIPTION                            0.040328
# WEATHER 2 CODE                                   0.962115
# WEATHER 2 DESCRIPTION                            0.962115
# PRIMARY CONTRIBUTING CIRCUMSTANCE CODE           0.032530
# PRIMARY CONTRIBUTING CIRCUMSTANCE DESCRIPTION    0.032530
# SCHOOL BUS INVOLVED CODE                         0.000028
# ...

# %%
percent_missing[percent_missing < 0.01]
# Out:
# CRASH DATETIME                      0.000006
# CRASH CLASSIFICATION CODE           0.000006
# CRASH CLASSIFICATION DESCRIPTION    0.000006
# SCHOOL BUS INVOLVED CODE            0.000028
# SCHOOL BUS INVOLVED DESCRIPTION     0.000028
# dtype: float64

# %%
percent_missing[percent_missing.between(0.01, 0.05)]
# Out:
# MANNER OF IMPACT CODE                            0.037270
# MANNER OF IMPACT DESCRIPTION                     0.037270
# ROAD SURFACE CODE                                0.039592
# ROAD SURFACE DESCRIPTION                         0.039592
# LIGHTING CONDITION CODE                          0.038726
# LIGHTING CONDITION DESCRIPTION                   0.038726
# WEATHER 1 CODE                                   0.040328
# WEATHER 1 DESCRIPTION                            0.040328
# PRIMARY CONTRIBUTING CIRCUMSTANCE CODE           0.032530
# PRIMARY CONTRIBUTING CIRCUMSTANCE DESCRIPTION    0.032530
# dtype: float64

# %%
percent_missing[percent_missing > 0.05]
# Out:
# WEATHER 2 CODE                    0.962115
# WEATHER 2 DESCRIPTION             0.962115
# WORK ZONE LOCATION CODE           0.992994
# WORK ZONE LOCATION DESCRIPTION    0.992994
# WORK ZONE TYPE CODE               0.992990
# WORK ZONE TYPE DESCRIPTION        0.992990
# dtype: float64

# %%
row_drop = list(percent_missing[percent_missing < 0.01].index)
row_drop
# Out:
# ['CRASH DATETIME',
#  'CRASH CLASSIFICATION CODE',
#  'CRASH CLASSIFICATION DESCRIPTION',
#  'SCHOOL BUS INVOLVED CODE',
#  'SCHOOL BUS INVOLVED DESCRIPTION']

# %%
row_fill = list(percent_missing[percent_missing.between(0.01, 0.05)].index)
row_fill
# Out:
# ['MANNER OF IMPACT CODE',
#  'MANNER OF IMPACT DESCRIPTION',
#  'ROAD SURFACE CODE',
#  'ROAD SURFACE DESCRIPTION',
#  'LIGHTING CONDITION CODE',
#  'LIGHTING CONDITION DESCRIPTION',
#  'WEATHER 1 CODE',
#  'WEATHER 1 DESCRIPTION',
#  'PRIMARY CONTRIBUTING CIRCUMSTANCE CODE',
#  'PRIMARY CONTRIBUTING CIRCUMSTANCE DESCRIPTION']

# %%
col_drop = list(percent_missing[percent_missing > 0.05].index)
col_drop
# Out:
# ['WEATHER 2 CODE',
#  'WEATHER 2 DESCRIPTION',
#  'WORK ZONE LOCATION CODE',
#  'WORK ZONE LOCATION DESCRIPTION',
#  'WORK ZONE TYPE CODE',
#  'WORK ZONE TYPE DESCRIPTION']

# %%
crash_df = crash_df.drop(col_drop, axis = 1)
crash_df
# Out:
#                       CRASH DATETIME  DAY OF WEEK CODE  \
# 0       11/18/2015 05:06:00 PM +0000                 4
# 1       10/11/2013 10:53:00 PM +0000                 6
# 2       04/17/2012 08:25:00 PM +0000                 3
# 3       07/24/2013 04:20:00 PM +0000                 4
# 4       09/18/2009 03:02:00 PM +0000                 6
# ...                              ...               ...
# 533110  04/21/2022 09:20:00 AM +0000                 5
# 533111  05/17/2018 08:39:00 PM +0000                 5
# 533112  03/23/2018 02:49:00 PM +0000                 6
# 533113  09/20/2020 02:43:00 AM +0000                 7
# 533114  08/25/2024 10:45:00 PM +0000                 1
#
#        DAY OF WEEK DESCRIPTION CRASH CLASSIFICATION CODE  \
# 0                    Wednesday                        03
# 1                       Friday                        03
# 2                      Tuesday                        02
# 3                    Wednesday                        02
# ...

# %%
crash_df = crash_df.dropna(subset = row_drop)
crash_df
# Out:
#                       CRASH DATETIME  DAY OF WEEK CODE  \
# 0       11/18/2015 05:06:00 PM +0000                 4
# 1       10/11/2013 10:53:00 PM +0000                 6
# 2       04/17/2012 08:25:00 PM +0000                 3
# 3       07/24/2013 04:20:00 PM +0000                 4
# 4       09/18/2009 03:02:00 PM +0000                 6
# ...                              ...               ...
# 533110  04/21/2022 09:20:00 AM +0000                 5
# 533111  05/17/2018 08:39:00 PM +0000                 5
# 533112  03/23/2018 02:49:00 PM +0000                 6
# 533113  09/20/2020 02:43:00 AM +0000                 7
# 533114  08/25/2024 10:45:00 PM +0000                 1
#
#        DAY OF WEEK DESCRIPTION CRASH CLASSIFICATION CODE  \
# 0                    Wednesday                        03
# 1                       Friday                        03
# 2                      Tuesday                        02
# 3                    Wednesday                        02
# ...

# %%
for col in row_fill:
    crash_df[col] = crash_df[col].fillna(crash_df[col].mode(dropna = True)[0])
crash_df
# Out:
# /var/folders/1c/47fsk5z56lq4c2qq6c1rfj7r0000gn/T/ipykernel_36651/701388996.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crash_df[col] = crash_df[col].fillna(crash_df[col].mode(dropna = True)[0])
#                       CRASH DATETIME  DAY OF WEEK CODE  \
# 0       11/18/2015 05:06:00 PM +0000                 4
# 1       10/11/2013 10:53:00 PM +0000                 6
# 2       04/17/2012 08:25:00 PM +0000                 3
# 3       07/24/2013 04:20:00 PM +0000                 4
# 4       09/18/2009 03:02:00 PM +0000                 6
# ...                              ...               ...
# 533110  04/21/2022 09:20:00 AM +0000                 5
# 533111  05/17/2018 08:39:00 PM +0000                 5
# ...

# %%
crash_df.isna().sum()
# Out:
# CRASH DATETIME                                   0
# DAY OF WEEK CODE                                 0
# DAY OF WEEK DESCRIPTION                          0
# CRASH CLASSIFICATION CODE                        0
# CRASH CLASSIFICATION DESCRIPTION                 0
# COLLISION ON PRIVATE PROPERTY                    0
# PEDESTRIAN INVOLVED                              0
# MANNER OF IMPACT CODE                            0
# MANNER OF IMPACT DESCRIPTION                     0
# ALCOHOL INVOLVED                                 0
# DRUG INVOLVED                                    0
# ROAD SURFACE CODE                                0
# ROAD SURFACE DESCRIPTION                         0
# LIGHTING CONDITION CODE                          0
# LIGHTING CONDITION DESCRIPTION                   0
# WEATHER 1 CODE                                   0
# WEATHER 1 DESCRIPTION                            0
# SEATBELT USED                                    0
# ...

# %%
crash_df.to_csv('clean_crash_data.csv', index = False)
